# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C://Users//Ananthram Vasu//Downloads//MultipleDisease Prediction//parkinsons.csv")

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df = df.drop(columns = 'name')

# %%
df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df_features = df.drop(columns = 'status')

# %%
df_features.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df_features.isnull().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# Detect outliers using IQR
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Outlier conditions (values outside 1.5*IQR range)
outliers = ((df_features < (Q1 - 1.5 * IQR)) | (df_features > (Q3 + 1.5 * IQR)))

# Count of outliers per column
outlier_counts = outliers.sum()

# Visualize using an improved box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_features, orient="h", palette="coolwarm", showfliers=True)
plt.title("Box Plot of Features (with Outliers)")
plt.xlabel("Values")
plt.ylabel("Features")
plt.show()

# Display count of outliers per feature
outlier_counts
# Out:
# MDVP:Fo(Hz)          0
# MDVP:Fhi(Hz)        11
# MDVP:Flo(Hz)         9
# MDVP:Jitter(%)      14
# MDVP:Jitter(Abs)     7
# MDVP:RAP            14
# MDVP:PPQ            15
# Jitter:DDP          14
# MDVP:Shimmer         8
# MDVP:Shimmer(dB)    10
# Shimmer:APQ3         6
# Shimmer:APQ5        13
# MDVP:APQ            12
# Shimmer:DDA          6
# NHR                 19
# HNR                  3
# RPDE                 0
# DFA                  0
# spread1              4
# spread2              2
# D2                   1
# PPE                  5
# dtype: int64

# %%
# Treating Outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Apply capping (Winsorization)
df_features = df_features.copy()
df_features = df_features.clip(lower=lower_bound, upper=upper_bound, axis=1)

# Verify if outliers are capped
outliers_after = ((df_features < (Q1 - 1.5 * IQR)) | (df_features > (Q3 + 1.5 * IQR))).sum()
outliers_after
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# Visualize using an improved box plot after outlier treatment
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_features, orient="h", palette="coolwarm", showfliers=True)
plt.title("Box Plot of Features (with Outliers)")
plt.xlabel("Values")
plt.ylabel("Features")
plt.show()

# %%
df1 = pd.concat([df['status'],df_features])

# %%
del df1

# %%
df_features.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370  0.005540     0.01109       0.04374             0.426  ...
# 1   0.00465  0.006960     0.01394       0.06134             0.626  ...
# 2   0.00544  0.007098     0.01633       0.05233             0.482  ...
# 3   0.00502  0.006980     0.01505       0.05492             0.517  ...
# 4   0.00655  0.007098     0.01966       0.06425             0.584  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...

# %%
df = df.reset_index(drop=True)
df_features = df_features.reset_index(drop=True)

df1 = pd.concat([df['status'], df_features], axis=1)

# %%
df1.head()
# Out:
#    status  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       1      119.992       157.302        74.997         0.00784
# 1       1      122.400       148.650       113.819         0.00968
# 2       1      116.682       131.111       111.555         0.01050
# 3       1      116.676       137.871       111.366         0.00997
# 4       1      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370  0.005540     0.01109       0.04374  ...
# 1           0.00008   0.00465  0.006960     0.01394       0.06134  ...
# 2           0.00009   0.00544  0.007098     0.01633       0.05233  ...
# 3           0.00009   0.00502  0.006980     0.01505       0.05492  ...
# 4           0.00011   0.00655  0.007098     0.01966       0.06425  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...

# %%
#1. Target Variable (status) Distribution
sns.countplot(x='status', data=df1)
plt.title("Status Count (0 = Healthy, 1 = Parkinson's)")
plt.show()

# %%
#Histplot
features = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
            'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
            'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
            'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA',
            'spread1', 'spread2', 'D2', 'PPE']

for col in features:
    sns.histplot(df1[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.show()

# %%
#Correlation Heatmap
plt.figure(figsize=(14, 12))
corr = df1.drop('status', axis=1).corr()
sns.heatmap(corr, annot=False, cmap='coolwarm', square=True)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#Pairplot
subset = ['MDVP:Fo(Hz)', 'MDVP:Jitter(%)', 'MDVP:Shimmer', 'NHR', 'HNR', 'status']
sns.pairplot(df[subset], hue='status')
plt.show()

# %%
#Boxplots (Feature vs. Status)
for col in features:
    plt.figure(figsize=(6, 4))
    sns.barplot(x='status', y=col, data=df1)
    plt.title(f'{col} by Status')
    plt.xlabel('Status')
    plt.ylabel(col)
    plt.xticks([0, 1], ['Healthy (0)', "Parkinson\'s (1)"])
    plt.tight_layout()
    plt.show()

# %%
#Violin Plots
for col in features:
    plt.figure(figsize=(6, 4))
    sns.violinplot(x='status', y=col, data=df1, palette='muted')
    plt.title(f'{col} Distribution by Status')
    plt.xticks([0, 1], ['Healthy (0)', "Parkinson\'s (1)"])
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Ananthram Vasu\AppData\Local\Temp\ipykernel_66760\1182859421.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df1, palette='muted')
# C:\Users\Ananthram Vasu\AppData\Local\Temp\ipykernel_66760\1182859421.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df1, palette='muted')
# C:\Users\Ananthram Vasu\AppData\Local\Temp\ipykernel_66760\1182859421.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df1, palette='muted')
# ...

# %%
#Pairplot (Feature Pair Interactions)
sns.pairplot(df1[['MDVP:Fo(Hz)', 'MDVP:Jitter(%)', 'NHR', 'RPDE', 'DFA', 'status']], hue='status', palette='Set1')
plt.show()

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split original data
X = df1.drop('status', axis=1)
y = df1['status']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split (before SMOTE)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# Apply SMOTE to training data only
sm = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = sm.fit_resample(X_train, y_train)

# %%
#Checking the resampled class balance of the target column
print(pd.Series(y_train_resampled).value_counts())
# Out:
# status
# 0    118
# 1    118
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

model = RandomForestClassifier(random_state=42)
model.fit(X_train_resampled, y_train_resampled)

y_pred = model.predict(X_test)

print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.93      0.90      0.91        29
#
#     accuracy                           0.87        39
#    macro avg       0.83      0.85      0.84        39
# weighted avg       0.88      0.87      0.87        39

# %%
#Decision Tree Classifier
from sklearn import tree
dtc = tree.DecisionTreeClassifier(random_state=42)
dtc.fit(X_train_resampled, y_train_resampled)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dtc.score(X_train_resampled, y_train_resampled)
# Out:
# 1.0

# %%
import pickle
with open('parkinsons_best_model.pkl', 'wb') as file:
    pickle.dump(dtc, file)
print("DataFrame saved as pickle file.")
# Out:
# DataFrame saved as pickle file.

# %%
prediction = dtc.predict(X_test)

# %%
for i in prediction:
    print(["Parkinson Found" if i == 1 else "Normal" ])
# Out:
# ['Normal']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Normal']
# ['Parkinson Found']
# ['Normal']
# ['Normal']
# ['Normal']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Normal']
# ['Normal']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Normal']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Normal']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Normal']
# ['Normal']
# ['Normal']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Parkinson Found']
# ['Normal']

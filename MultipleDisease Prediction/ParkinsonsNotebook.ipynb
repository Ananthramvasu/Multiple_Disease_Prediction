# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_park = pd.read_csv("C://Users//Ananthram Vasu//Downloads//MultipleDisease Prediction//parkinsons.csv")

# %%
df_park
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
df_park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df_park.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df_park.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
df_park.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
zero_counts = (df_park == 0).sum()
print("Columns with zero values:")
print(zero_counts[zero_counts > 0])
# Out:
# Columns with zero values:
# status    48
# dtype: int64

# %%
# Identify columns where 50% or more values are zero
columns_with_zeros = zero_counts[zero_counts >= 0.5].index
columns_with_zeros
# Out:
# Index(['status'], dtype='object')

# %%
sns.boxplot(data=df_park)
# Out:
# <Axes: >

# %%
for col in columns_with_zeros:
    df_park[col] = df_park[col].replace(0, df_park[col].median())

# %%
zero_counts = (df_park == 0).sum()
print("Columns with zero values:")
print(zero_counts[zero_counts > 0])
# Out:
# Columns with zero values:
# Series([], dtype: int64)

# %%
df_park.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
# Removing the 'name' column as it's non-numeric
df_numeric = df_park.drop(columns=['name'])

# %%
df_numeric.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
# Detect outliers using IQR
Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)
IQR = Q3 - Q1

# Outlier conditions (values outside 1.5*IQR range)
outliers = ((df_numeric < (Q1 - 1.5 * IQR)) | (df_numeric > (Q3 + 1.5 * IQR)))

# Count of outliers per column
outlier_counts = outliers.sum()

# Visualize using an improved box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_numeric, orient="h", palette="coolwarm", showfliers=True)
plt.title("Box Plot of Features (with Outliers)")
plt.xlabel("Values")
plt.ylabel("Features")
plt.show()

# Display count of outliers per feature
outlier_counts
# Out:
# MDVP:Fo(Hz)          0
# MDVP:Fhi(Hz)        11
# MDVP:Flo(Hz)         9
# MDVP:Jitter(%)      14
# MDVP:Jitter(Abs)     7
# MDVP:RAP            14
# MDVP:PPQ            15
# Jitter:DDP          14
# MDVP:Shimmer         8
# MDVP:Shimmer(dB)    10
# Shimmer:APQ3         6
# Shimmer:APQ5        13
# MDVP:APQ            12
# Shimmer:DDA          6
# NHR                 19
# HNR                  3
# status               0
# RPDE                 0
# DFA                  0
# spread1              4
# spread2              2
# D2                   1
# PPE                  5
# dtype: int64

# %%
# Treating Outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Apply capping (Winsorization)
df_numeric= df_numeric.copy()
df_numeric = df_numeric.clip(lower=lower_bound, upper=upper_bound, axis=1)

# Verify if outliers are capped
outliers_after = ((df_numeric < (Q1 - 1.5 * IQR)) | (df_numeric > (Q3 + 1.5 * IQR))).sum()
outliers_after
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# Visualizing after outlier treatment
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_numeric, orient="h", palette="coolwarm", showfliers=True)
plt.title("Box Plot of Features (with Outliers)")
plt.xlabel("Values")
plt.ylabel("Features")
plt.show()

outliers_after
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
scaler = StandardScaler()

# Apply scaling to the dataset (excluding the target variable 'status')
X_scaled = scaler.fit_transform(df_numeric.drop(columns=['status']))

# Convert back to DataFrame for better readability
df_parkscale = pd.DataFrame(X_scaled, columns=df_numeric.drop(columns=['status']).columns)

# Add back the target variable 'status'
df_parkscale['status'] = df_numeric['status'].values

df_parkscale
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0      -0.829300     -0.500094     -0.964110        0.701875
# 1      -0.770972     -0.638805     -0.050885        1.308591
# 2      -0.909476     -0.919993     -0.104142        1.578975
# 3      -0.909622     -0.811616     -0.108588        1.404215
# 4      -0.925657     -0.748930     -0.125313        2.350560
# ..           ...           ...           ...             ...
# 190     0.483467      0.681092     -0.510956       -0.369770
# 191     1.339202      1.034426     -0.623233       -0.023547
# 192     0.495578      0.825815     -0.980812        2.476684
# 193     1.078761      2.721059     -0.966298        0.556790
# 194     1.454817      1.150819     -0.894105       -0.013654
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            1.017692  0.440015  1.437914    0.438206      0.885615
# 1            1.382624  0.999991  2.285930    0.998426      1.943849
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn import svm
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# %%
import numpy as np
# Check class distribution before splitting
print("Class distribution in original dataset:", np.unique(y, return_counts=True))
# Out:
# Class distribution in original dataset: (array([1], dtype=int64), array([195], dtype=int64))

# %%
from collections import Counter

print("Class distribution in y_train:", Counter(y_train))
print("Class distribution in y_test:", Counter(y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 from collections import Counter
# ----> 3 print("Class distribution in y_train:", Counter(y_train))
#       4 print("Class distribution in y_test:", Counter(y_test))
#
# NameError: name 'y_train' is not defined

# %%
print("Original class distribution:", Counter(y))
# Out:
# Original class distribution: Counter({1: 195})

# %%
X = df_parkscale[['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)','MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP','MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5','MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1','spread2', 'D2', 'PPE']]
y = df_parkscale['status']

# %%
df_split = pd.read_csv("C://Users//Ananthram Vasu//Downloads//parkinsons.csv")

# %%
# Perform stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y)

#X_train,X_test,y_train,y_test = train_test_split(X, y)

# %%
#Logistic Regression
lgr = LogisticRegression()
lgr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lgr.score(X_train,y_train)
# Out:
# 0.8835616438356164

# %%
#Linear Regression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.5227468298508605

# %%
#Ridge
rd = Ridge()
rd.fit(X_train,y_train)
# Out:
# Ridge()

# %%
rd.score(X_train,y_train)
# Out:
# 0.5122029256732155

# %%
#Lasso
ls = Lasso()
ls.fit(X_train,y_train)
# Out:
# Lasso()

# %%
ls.score(X_train,y_train)
# Out:
# 0.0

# %%
#SVM model
sv = svm.SVC(kernel='linear', random_state=42)
sv.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
sv.score(X_train,y_train)
# Out:
# 0.8972602739726028

# %%
#Decision Tree Classifier
dtc = tree.DecisionTreeClassifier(random_state=42)
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dtc.score(X_train,y_train)
# Out:
# 1.0

# %%
#Elastic net cv
en = ElasticNet()
en.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
en.score(X_train,y_train)
# Out:
# 0.0

# %%
#By comparing the scores decision tree classifier gives 100% accuracy

# %%
prediction = dtc.predict(X_test)

# %%
prediction = ["Parkinson Predicted" if val == 1 else "Nothing is Predicted" for val in prediction]
for i, pred in enumerate(prediction[:30]):  # Print first 20 predictions
    print(f"Sample {i+1}: {pred}")
# Out:
# Sample 1: Parkinson Predicted
# Sample 2: Parkinson Predicted
# Sample 3: Parkinson Predicted
# Sample 4: Parkinson Predicted
# Sample 5: Parkinson Predicted
# Sample 6: Parkinson Predicted
# Sample 7: Parkinson Predicted
# Sample 8: Parkinson Predicted
# Sample 9: Parkinson Predicted
# Sample 10: Parkinson Predicted
# Sample 11: Parkinson Predicted
# Sample 12: Parkinson Predicted
# Sample 13: Parkinson Predicted
# Sample 14: Nothing is Predicted
# Sample 15: Parkinson Predicted
# Sample 16: Parkinson Predicted
# Sample 17: Parkinson Predicted
# Sample 18: Parkinson Predicted
# Sample 19: Parkinson Predicted
# Sample 20: Nothing is Predicted
# Sample 21: Parkinson Predicted
# Sample 22: Nothing is Predicted
# Sample 23: Parkinson Predicted
# Sample 24: Parkinson Predicted
# Sample 25: Parkinson Predicted
# Sample 26: Nothing is Predicted
# Sample 27: Nothing is Predicted
# Sample 28: Parkinson Predicted
# Sample 29: Parkinson Predicted
# Sample 30: Parkinson Predicted

# %%
import pickle
with open('ParkinsonsNotebook.pkl', 'wb') as file:
    pickle.dump(dtc, file)

print("DataFrame saved as pickle file.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pickle
#       2 with open('ParkinsonsNotebook.pkl', 'wb') as file:
# ----> 3     pickle.dump(dtc, file)
#       5 print("DataFrame saved as pickle file.")
#
# NameError: name 'dtc' is not defined
